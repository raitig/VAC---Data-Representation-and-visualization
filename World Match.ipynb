# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('/content/WorldCupMatches.csv')
df
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
df.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
df.tail()
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4567   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4568   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4567              NaN            NaN            NaN         NaN
# 4568              NaN            NaN            NaN         NaN
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4567                   NaN                   NaN     NaN         NaN
# ...

# %%
df.shape
# Out:
# (4572, 20)

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
print(df[345:])
# Out:
#         Year              Datetime    Stage            Stadium        City  \
# 345   1982.0  28 Jun 1982 - 21:00   Group 1           Camp Nou  Barcelona
# 346   1982.0  29 Jun 1982 - 17:15   Group 3             Sarria  Barcelona
# 347   1982.0  29 Jun 1982 - 21:00   Group 2  Santiago Bernabeu     Madrid
# 348   1982.0  01 Jul 1982 - 17:15   Group 4   Vicente Calderon     Madrid
# 349   1982.0  01 Jul 1982 - 21:00   Group 1           Camp Nou  Barcelona
# ...      ...                   ...      ...                ...         ...
# 4567     NaN                   NaN      NaN                NaN         NaN
# 4568     NaN                   NaN      NaN                NaN         NaN
# 4569     NaN                   NaN      NaN                NaN         NaN
# 4570     NaN                   NaN      NaN                NaN         NaN
# 4571     NaN                   NaN      NaN                NaN         NaN
#
# ...

# %%
print(df[:456])
# Out:
#        Year              Datetime        Stage                 Stadium  \
# 0    1930.0  13 Jul 1930 - 15:00       Group 1                 Pocitos
# 1    1930.0  13 Jul 1930 - 15:00       Group 4          Parque Central
# 2    1930.0  14 Jul 1930 - 12:45       Group 2          Parque Central
# 3    1930.0  14 Jul 1930 - 14:50       Group 3                 Pocitos
# 4    1930.0  15 Jul 1930 - 16:00       Group 1          Parque Central
# ..      ...                   ...          ...                     ...
# 451  1990.0  24 Jun 1990 - 21:00   Round of 16         Giuseppe Meazza
# 452  1990.0  25 Jun 1990 - 17:00   Round of 16          Luigi Ferraris
# 453  1990.0  25 Jun 1990 - 21:00   Round of 16         Stadio Olimpico
# 454  1990.0  26 Jun 1990 - 17:00   Round of 16  Marc Antonio Bentegodi
# 455  1990.0  26 Jun 1990 - 21:00   Round of 16         Renato Dall Ara
#
#             City           Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
print(df[250:450])
# Out:
#        Year               Datetime        Stage                 Stadium  \
# 250  1974.0   22 Jun 1974 - 16:00       Group 2             Parkstadion
# 251  1974.0  22 June 1974 - 19:30       Group 1        Volksparkstadion
# 252  1974.0   23 Jun 1974 - 16:00       Group 3        Westfalenstadion
# 253  1974.0   23 Jun 1974 - 16:00       Group 4          Olympiastadion
# 254  1974.0   23 Jun 1974 - 16:00       Group 3            Rheinstadion
# ..      ...                    ...          ...                     ...
# 445  1990.0   21 Jun 1990 - 17:00       Group E  Marc Antonio Bentegodi
# 446  1990.0   21 Jun 1990 - 21:00       Group F          Della Favorita
# 447  1990.0   21 Jun 1990 - 21:00       Group F               Sant Elia
# 448  1990.0   23 Jun 1990 - 17:00   Round of 16               San Paolo
# 449  1990.0   23 Jun 1990 - 21:00   Round of 16       Stadio San Nicola
#
#                City           Home Team Name  Home Team Goals  \
# ...

# %%
print(df.loc[100])
# Out:
# Year                                      1954.0
# Datetime                    04 Jul 1954 - 17:00
# Stage                                      Final
# Stadium                         Wankdorf Stadium
# City                                      Berne
# Home Team Name                        Germany FR
# Home Team Goals                              3.0
# Away Team Goals                              2.0
# Away Team Name                           Hungary
# Win conditions
# Attendance                               62500.0
# Half-time Home Goals                         2.0
# Half-time Away Goals                         2.0
# Referee                       LING William (ENG)
# Assistant 1             ORLANDINI Vincenzo (ITA)
# Assistant 2             GRIFFITHS Benjamin (WAL)
# RoundID                                   3484.0
# MatchID                                   1278.0
# Home Team Initials                           FRG
# Away Team Initials                           HUN
# ...

# %%
print(df.head(100))
# Out:
#       Year              Datetime                  Stage           Stadium  \
# 0   1930.0  13 Jul 1930 - 15:00                 Group 1           Pocitos
# 1   1930.0  13 Jul 1930 - 15:00                 Group 4    Parque Central
# 2   1930.0  14 Jul 1930 - 12:45                 Group 2    Parque Central
# 3   1930.0  14 Jul 1930 - 14:50                 Group 3           Pocitos
# 4   1930.0  15 Jul 1930 - 16:00                 Group 1    Parque Central
# ..     ...                   ...                    ...               ...
# 95  1954.0  27 Jun 1954 - 17:00          Quarter-finals        Charmilles
# 96  1954.0  27 Jun 1954 - 17:00          Quarter-finals  Wankdorf Stadium
# 97  1954.0  30 Jun 1954 - 18:00             Semi-finals         St. Jakob
# 98  1954.0  30 Jun 1954 - 18:00             Semi-finals       La Pontaise
# 99  1954.0  03 Jul 1954 - 17:00   Match for third place          Hardturm
#
#            City Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
print(df.tail(100))
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4472   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4473   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4474   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4475   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4476   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# ...    ...      ...   ...     ...  ...            ...              ...
# 4567   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4568   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# ...

# %%
df.groupby('Datetime').count()
# Out:
#                       Year  Stage  Stadium  City  Home Team Name  \
# Datetime
# 01 Jul 1950 - 15:00      1      1        1     1               1
# 01 Jul 1982 - 17:15      1      1        1     1               1
# 01 Jul 1982 - 21:00      1      1        1     1               1
# 01 Jul 1990 - 17:00      1      1        1     1               1
# 01 Jul 1990 - 21:00      1      1        1     1               1
# ...                    ...    ...      ...   ...             ...
# 31 May 1934 - 16:30      4      4        4     4               4
# 31 May 1962 - 15:00      4      4        4     4               4
# 31 May 1970 - 12:00      1      1        1     1               1
# 31 May 1986 - 12:00      1      1        1     1               1
# 31 May 2002 - 20:30      1      1        1     1               1
#
#                       Home Team Goals  Away Team Goals  Away Team Name  \
# Datetime
# 01 Jul 1950 - 15:00                 1                1               1
# ...

# %%
df.isnull()
# Out:
#        Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0     False     False  False    False  False           False            False
# 1     False     False  False    False  False           False            False
# 2     False     False  False    False  False           False            False
# 3     False     False  False    False  False           False            False
# 4     False     False  False    False  False           False            False
# ...     ...       ...    ...      ...    ...             ...              ...
# 4567   True      True   True     True   True            True             True
# 4568   True      True   True     True   True            True             True
# 4569   True      True   True     True   True            True             True
# 4570   True      True   True     True   True            True             True
# 4571   True      True   True     True   True            True             True
#
# ...

# %%
df.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
sns.barplot(x='Datetime' , y='City', data=df)
# Out:
# <Axes: xlabel='Datetime', ylabel='City'>

# %%
sns.barplot(x='Stage',y='Home Team Name',data=df)
# Out:
# <Axes: xlabel='Stage', ylabel='Home Team Name'>

# %%
sns.pairplot(df,hue='City')

# %%
sns.pairplot(df,hue='Stadium')

# %%
sns.scatterplot(x='Datetime',y='City',data=df)
# Out:
# <Axes: xlabel='Datetime', ylabel='City'>

# %%
sns.scatterplot(x='Stage',y='Stadium',data=df)
# Out:
# <Axes: xlabel='Stage', ylabel='Stadium'>

# %%
Year=df['Year']
plt.plot(Year)
plt.show()

# %%
Year=df['Year']
plt.plot(Year,color='red',label="Year")
plt.legend()
plt.show()

# %%
sns.barplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
sns.barplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
df['MatchID'].fillna(df['MatchID'].mean(), inplace=True)
df.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                    0
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
sns.displot(df['Year'])
