# %%
import seaborn as sns # seaborn library is used to plot any diagrame 1-d or 2-d using oython
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
DataFrame =pd.read_csv("/content/Titanic.csv")
print(DataFrame)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(DataFrame.shape)
# Out:
# (891, 12)

# %%
print(DataFrame.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(DataFrame.info)
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
print(DataFrame[100:])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 100          101         0       3                   Petranec, Miss. Matilda
# 101          102         0       3          Petroff, Mr. Pastcho ("Pentcho")
# 102          103         0       1                 White, Mr. Richard Frasar
# 103          104         0       3                Johansson, Mr. Gustaf Joel
# 104          105         0       3            Gustafsson, Mr. Anders Vilhelm
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
print(DataFrame.describe)
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
Print(DataFrame[45:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-034a98d464c7> in <cell line: 1>()
# ----> 1 Print(DataFrame[45:])
#
# NameError: name 'Print' is not defined

# %%
Print(DataFrame[2:67])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e0cb8e6eb726> in <cell line: 1>()
# ----> 1 Print(DataFrame[2:67])
#
# NameError: name 'Print' is not defined

# %%
DataFrame.isnull() # it finds the null values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
DataFrame.isnull().sum() # it finds the null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
DataFrame.nunique() # it finds the unique values
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
DataFrame.corr() # it finds the correlation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8edd9fa6d317> in <cell line: 1>()
# ----> 1 DataFrame.corr() # it finds the correlation
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
DataFrame.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
import seaborn as sns
import pandas as pd # Assuming DataFrame comes from pandas

# Select only numerical columns before calculating correlation
numerical_df = DataFrame.select_dtypes(include=['float', 'int'])
corr_matrix = numerical_df.corr()

sns.heatmap(corr_matrix, annot=True, cmap="mako")
# Out:
# <Axes: >

# %%
sns.jointplot(x='total_bill', y='tip', DataFrame=DataFrame, kind='reg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-be202f395f67> in <cell line: 1>()
# ----> 1 sns.jointplot(x='total_bill', y='tip', DataFrame=DataFrame, kind='reg')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2241
#    2242     # Initialize the JointGrid object
# -> 2243     grid = JointGrid(
#    2244         data=data, x=x, y=y, hue=hue,
#    2245         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in __init__(self, data, x, y, hue, height, ratio, space, palette, hue_order, hue_norm, dropna, xlim, ylim, marginal_ticks)
#    1726
#    1727         # Process the input variables
# ...

# %%
sns.barplot("x='sex', y='total_bill', DataFrame=DataFrame")
# Out:
# <Axes: >

# %%
DataFrame.groupby('day').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-da2f9d0f89c4> in <cell line: 1>()
# ----> 1 DataFrame.groupby('day').count()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8250         axis = self._get_axis_number(axis)
#    8251
# -> 8252         return DataFrameGroupBy(
#    8253             obj=self,
#    8254             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     929
#     930         if grouper is None:
# --> 931             grouper, exclusions, obj = get_grouper(
#     932                 obj,
#     933                 keys,
#
# ...

# %%
DataFrame.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
DataFrame.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
age=DataFrame['Age']
plt.plot(age)
plt.show()

# %%
passenger=DataFrame["Survived"]
plt.plot(passenger)
plt.show()

# %%
age=DataFrame['Age']
plt.plot(age,color='Green')
plt.show()

# %%
age=DataFrame['Age']
plt.plot(age,color='Red',label="Age")
plt.legend()
plt.show()

# %%
sns.boxplot(DataFrame['Age']) # there is loats of null values and outliers in age columns
# Out:
# <Axes: ylabel='Age'>

# %%
DataFrame.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# how to handle or clean missing value
DataFrame['Age'].fillna(DataFrame['Age'].mean(), inplace=True)
DataFrame.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# How to plot distribution ploting
sns.displot(x='Age',data=DataFrame)

# %%
# correlation : how more than two categorical or numerical attribute are related to each othe
corr=DataFrame[['Age','Fare','Pclass']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >
