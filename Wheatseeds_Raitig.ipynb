# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/wheat-seeds.csv")
print(df)
# Out:
#      15.26  14.84   0.871  5.763  3.312  2.221   5.22  1
# 0    14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 1    14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 2    13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 3    16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1
# 4    14.38  14.21  0.8951  5.386  3.312  2.462  4.956  1
# ..     ...    ...     ...    ...    ...    ...    ... ..
# 204  12.19  13.20  0.8783  5.137  2.981  3.631  4.870  3
# 205  11.23  12.88  0.8511  5.140  2.795  4.325  5.003  3
# 206  13.20  13.66  0.8883  5.236  3.232  8.315  5.056  3
# 207  11.84  13.21  0.8521  5.175  2.836  3.598  5.044  3
# 208  12.30  13.34  0.8684  5.243  2.974  5.637  5.063  3
#
# [209 rows x 8 columns]

# %%
df.head()
# Out:
#    15.26  14.84   0.871  5.763  3.312  2.221   5.22  1
# 0  14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 1  14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 2  13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 3  16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1
# 4  14.38  14.21  0.8951  5.386  3.312  2.462  4.956  1

# %%
df.describe()
# Out:
#             15.26       14.84       0.871       5.763       3.312       2.221  \
# count  209.000000  209.000000  209.000000  209.000000  209.000000  209.000000
# mean    14.845550   14.557943    0.870999    5.627890    3.258349    3.707278
# std      2.916545    1.308949    0.023686    0.444029    0.378603    1.503657
# min     10.590000   12.410000    0.808100    4.899000    2.630000    0.765100
# 25%     12.260000   13.450000    0.856700    5.262000    2.941000    2.587000
# 50%     14.340000   14.290000    0.873500    5.520000    3.232000    3.600000
# 75%     17.320000   15.730000    0.887900    5.980000    3.562000    4.773000
# max     21.180000   17.250000    0.918300    6.675000    4.033000    8.456000
#
#              5.22           1
# count  209.000000  209.000000
# mean     5.408971    2.004785
# std      0.492487    0.817463
# min      4.519000    1.000000
# 25%      5.045000    1.000000
# 50%      5.224000    2.000000
# 75%      5.877000    3.000000
# max      6.550000    3.000000

# %%
df.isnull().sum()
# Out:
# 15.26    0
# 14.84    0
# 0.871    0
# 5.763    0
# 3.312    0
# 2.221    0
# 5.22     0
# 1        0
# dtype: int64

# %%
dt=df.iloc[0]
print(dt)
# Out:
# 15.26    14.8800
# 14.84    14.5700
# 0.871     0.8811
# 5.763     5.5540
# 3.312     3.3330
# 2.221     1.0180
# 5.22      4.9560
# 1         1.0000
# Name: 0, dtype: float64

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#       0.871  1  14.84  15.26  2.221  3.312   5.22  5.763
# 0    0.8811  1  14.57  14.88  1.018  3.333  4.956  5.554
# 1    0.9050  1  14.09  14.29  2.699  3.337  4.825  5.291
# 2    0.8955  1  13.94  13.84  2.259  3.379  4.805  5.324
# 3    0.9034  1  14.99  16.14  1.355  3.562  5.175  5.658
# 4    0.8951  1  14.21  14.38  2.462  3.312  4.956  5.386
# ..      ... ..    ...    ...    ...    ...    ...    ...
# 204  0.8783  3  13.20  12.19  3.631  2.981  4.870  5.137
# 205  0.8511  3  12.88  11.23  4.325  2.795  5.003  5.140
# 206  0.8883  3  13.66  13.20  8.315  3.232  5.056  5.236
# 207  0.8521  3  13.21  11.84  3.598  2.836  5.044  5.175
# 208  0.8684  3  13.34  12.30  5.637  2.974  5.063  5.243
#
# [209 rows x 8 columns]

# %%
print(df.iloc[2:4,3:5])
# Out:
#    5.763  3.312
# 2  5.324  3.379
# 3  5.658  3.562

# %%
print(df.iloc[:,3:5])
# Out:
#      5.763  3.312
# 0    5.554  3.333
# 1    5.291  3.337
# 2    5.324  3.379
# 3    5.658  3.562
# 4    5.386  3.312
# ..     ...    ...
# 204  5.137  2.981
# 205  5.140  2.795
# 206  5.236  3.232
# 207  5.175  2.836
# 208  5.243  2.974
#
# [209 rows x 2 columns]

# %%
dt=df.stack(future_stack=True)
print(dt)
# Out:
# 0    15.26    14.8800
#      14.84    14.5700
#      0.871     0.8811
#      5.763     5.5540
#      3.312     3.3330
#                ...
# 208  5.763     5.2430
#      3.312     2.9740
#      2.221     5.6370
#      5.22      5.0630
#      1         3.0000
# Length: 1672, dtype: float64

# %%
df.plot()
plt.show()

# %%
df.plot(kind='hist')
plt.show()

# %%
df=np.arange(10,15)
df1=np.array([11,12,13,14,15])
print(df)
print(df1)
np.corrcoef(df,df1)
# Out:
# [10 11 12 13 14]
# [11 12 13 14 15]
# array([[1., 1.],
#        [1., 1.]])

# %%
df=np.arange(25,30)
df1=np.array([11,15,23,25,29])
r=np.corrcoef(df,df1)
r1=scipy.stats.pearsonr(df,df1)
print(r1[0],r1[1])
r2=scipy.stats.spearmanr(df,df1)
print(r2[0],r2[1])
r3=scipy.stats.kendalltau(df,df1)
print([r3[0],r3[1]])
# Out:
# 0.9825113063742752 0.0027690279453106
# 0.9999999999999999 1.4042654220543672e-24
# [0.9999999999999999, 0.016666666666666666]

# %%
df=np.arange(25,30)
df1=np.array([11,15,23,25,29])
r=np.corrcoef(df,df1)
r1,p1=scipy.stats.pearsonr(df,df1)
print(r1,p1)
r2,p2=scipy.stats.spearmanr(df,df1)
print(r2,p2)
r3,p3=scipy.stats.kendalltau(df,df1)
print(r3,p3)
# Out:
# 0.9825113063742752 0.0027690279453106
# 0.9999999999999999 1.4042654220543672e-24
# 0.9999999999999999 0.016666666666666666

# %%
reg=scipy.stats.linregress(df,df1)
print(reg)
print(reg.slope)
print(reg.rvalue)
print(reg.pvalue)
print(reg.stderr)
print(reg.intercept)
print(reg.intercept_stderr)
# Out:
# LinregressResult(slope=4.6000000000000005, intercept=-103.60000000000002, rvalue=0.9825113063742752, pvalue=0.002769027945310598, stderr=0.503322295684715, intercept_stderr=13.608330781791919)
# 4.6000000000000005
# 0.9825113063742752
# 0.002769027945310598
# 0.503322295684715
# -103.60000000000002
# 13.608330781791919
