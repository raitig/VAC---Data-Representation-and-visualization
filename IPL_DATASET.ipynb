# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv('/content/ipl.csv')
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
df.shape
# Out:
# (1095, 20)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
print(df[100:])
# Out:
#            id season            city        date   match_type  \
# 100    392225   2009          Durban  2009-05-14       League
# 101    392226   2009    Bloemfontein  2009-05-15       League
# 102    392227   2009  Port Elizabeth  2009-05-16       League
# 103    392228   2009    Johannesburg  2009-05-16       League
# 104    392229   2009    Johannesburg  2009-05-17       League
# ...       ...    ...             ...         ...          ...
# 1090  1426307   2024       Hyderabad  2024-05-19       League
# 1091  1426309   2024       Ahmedabad  2024-05-21  Qualifier 1
# 1092  1426310   2024       Ahmedabad  2024-05-22   Eliminator
# 1093  1426311   2024         Chennai  2024-05-24  Qualifier 2
# 1094  1426312   2024         Chennai  2024-05-26        Final
#
#       player_of_match                                              venue  \
# 100          SK Warne                                          Kingsmead
# ...

# %%
print(df[:90])
# Out:
#         id   season        city        date match_type player_of_match  \
# 0   335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1   335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2   335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3   335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4   335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# ..     ...      ...         ...         ...        ...             ...
# 85  392210     2009      Durban  2009-05-05     League        GC Smith
# 86  392211     2009      Durban  2009-05-05     League       G Gambhir
# 87  392212     2009   Centurion  2009-05-06     League       RG Sharma
# 88  392213     2009   Centurion  2009-05-07     League         A Singh
# 89  392214     2009   Centurion  2009-05-07     League       ML Hayden
#
#                                          venue                        team1  \
# ...

# %%
print(df[56:87])
# Out:
#         id   season            city        date  match_type   player_of_match  \
# 56  336039  2007/08          Mumbai  2008-05-31  Semi Final           M Ntini
# 57  336040  2007/08          Mumbai  2008-06-01       Final         YK Pathan
# 58  392181     2009       Cape Town  2009-04-18      League      SR Tendulkar
# 59  392182     2009       Cape Town  2009-04-18      League          R Dravid
# 60  392183     2009       Cape Town  2009-04-19      League        DL Vettori
# 61  392184     2009       Cape Town  2009-04-19      League          RP Singh
# 62  392185     2009  Port Elizabeth  2009-04-20      League    M Muralitharan
# 63  392186     2009          Durban  2009-04-21      League          CH Gayle
# 64  392188     2009       Cape Town  2009-04-22      League      AC Gilchrist
# 65  392189     2009          Durban  2009-04-23      League    AB de Villiers
# 66  392190     2009       Cape Town  2009-04-23      League         YK Pathan
# ...

# %%
df.head(16)
# Out:
#         id   season        city        date match_type player_of_match  \
# 0   335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1   335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2   335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3   335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4   335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5   335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6   335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7   335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8   335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9   335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
# 10  335992  2007/08   Bangalore  2008-04-26     League       SR Watson
# 11  335993  2007/08     Chennai  2008-04-26     League        JDP Oram
# ...

# %%
df.tail(56)
# Out:
#            id season           city        date   match_type  \
# 1039  1422134   2024  Visakhapatnam  2024-04-03       League
# 1040  1422135   2024      Ahmedabad  2024-04-04       League
# 1041  1422136   2024      Hyderabad  2024-04-05       League
# 1042  1422137   2024         Jaipur  2024-04-06       League
# 1043  1422138   2024         Mumbai  2024-04-07       League
# 1044  1422139   2024        Lucknow  2024-04-07       League
# 1045  1426260   2024        Chennai  2024-04-08       League
# 1046  1426261   2024         Mohali  2024-04-09       League
# 1047  1426262   2024         Jaipur  2024-04-10       League
# 1048  1426263   2024         Mumbai  2024-04-11       League
# 1049  1426264   2024        Lucknow  2024-04-12       League
# 1050  1426265   2024         Mohali  2024-04-13       League
# 1051  1426266   2024        Kolkata  2024-04-14       League
# 1052  1426267   2024         Mumbai  2024-04-14       League
# ...

# %%
df.groupby('season').count()
# Out:
#          id  city  date  match_type  player_of_match  venue  team1  team2  \
# season
# 2007/08  58    58    58          58               58     58     58     58
# 2009     57    57    57          57               57     57     57     57
# 2009/10  60    60    60          60               60     60     60     60
# 2011     73    73    73          73               72     73     73     73
# 2012     74    74    74          74               74     74     74     74
# 2013     76    76    76          76               76     76     76     76
# 2014     60    47    60          60               60     60     60     60
# 2015     59    59    59          59               57     59     59     59
# 2016     60    60    60          60               60     60     60     60
# 2017     59    59    59          59               59     59     59     59
# 2018     60    60    60          60               60     60     60     60
# 2019     60    60    60          60               59     60     60     60
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
sns.pairplot(df,hue='city')

# %%
sns.barplot(x='city',y='date',data=df)
# Out:
# <Axes: xlabel='city', ylabel='date'>

# %%
sns.scatterplot(x='season' , y='toss_decision',data=df)
# Out:
# <Axes: xlabel='season', ylabel='toss_decision'>

# %%
player_of_match=df['player_of_match']
plt.plot=(player_of_match)
plt.show()
