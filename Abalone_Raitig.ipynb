# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/abalone.csv")
print(df)
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
df.head()
# Out:
#    M  0.455  0.365  0.095   0.514  0.2245   0.101   0.15  15
# 0  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 1  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 2  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 3  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7
# 4  I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.120   8

# %%
df.describe()
# Out:
#              0.455        0.365        0.095        0.514      0.2245  \
# count  4176.000000  4176.000000  4176.000000  4176.000000  4176.00000
# mean      0.524009     0.407892     0.139527     0.828818     0.35940
# std       0.120103     0.099250     0.041826     0.490424     0.22198
# min       0.075000     0.055000     0.000000     0.002000     0.00100
# 25%       0.450000     0.350000     0.115000     0.441500     0.18600
# 50%       0.545000     0.425000     0.140000     0.799750     0.33600
# 75%       0.615000     0.480000     0.165000     1.153250     0.50200
# max       0.815000     0.650000     1.130000     2.825500     1.48800
#
#              0.101         0.15           15
# count  4176.000000  4176.000000  4176.000000
# mean      0.180613     0.238852     9.932471
# std       0.109620     0.139213     3.223601
# min       0.000500     0.001500     1.000000
# 25%       0.093375     0.130000     8.000000
# 50%       0.171000     0.234000     9.000000
# ...

# %%
df.isnull().sum()
# Out:
# M         0
# 0.455     0
# 0.365     0
# 0.095     0
# 0.514     0
# 0.2245    0
# 0.101     0
# 0.15      0
# 15        0
# dtype: int64

# %%
dt=df.iloc[2]
print(df)
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
#
# [4176 rows x 9 columns]

# %%
print(df.iloc[2:4,3:5])
# Out:
#    0.095  0.514
# 2  0.125  0.516
# 3  0.080  0.205

# %%
print(df.iloc[:,3:5])
# Out:
#       0.095   0.514
# 0     0.090  0.2255
# 1     0.135  0.6770
# 2     0.125  0.5160
# 3     0.080  0.2050
# 4     0.095  0.3515
# ...     ...     ...
# 4171  0.165  0.8870
# 4172  0.135  0.9660
# 4173  0.205  1.1760
# 4174  0.150  1.0945
# 4175  0.195  1.9485
#
# [4176 rows x 2 columns]

# %%
dt=df.stack(future_stack=True)
print(dt)
# Out:
# 0     M              M
#       0.455       0.35
#       0.365      0.265
#       0.095       0.09
#       0.514     0.2255
#                  ...
# 4175  0.514     1.9485
#       0.2245    0.9455
#       0.101     0.3765
#       0.15       0.495
#       15            12
# Length: 37584, dtype: object

# %%
df.plot()
plt.show()

# %%
df.plot(kind='hist')
plt.show()

# %%
df=np.arange(20,25)
df1=np.array([11,12,13,14,15])
np.corrcoef(df,df1)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
df=np.arange(30,40)
df1=np.array([11,13,15,21,23,25,29,32,34,35])
r=np.corrcoef(df,df1)
r1,p1=scipy.stats.pearsonr(df,df1)
print(r1,p1)
r2,p2=scipy.stats.spearmanr(df,df1)
print(r2,p2)
r3,p3=scipy.stats.kendalltau(df,df1)
print(r3,p3)
# Out:
# 0.9921877927164613 1.6143432802063756e-08
# 0.9999999999999999 6.646897422032013e-64
# 0.9999999999999999 5.511463844797178e-07

# %%
df=np.arange(25,30)
df1=np.array([11,15,23,25,29])
r=np.corrcoef(df,df1)
r1=scipy.stats.pearsonr(df,df1)
print(r1[0],r1[1])
r2=scipy.stats.spearmanr(df,df1)
print(r2[0],r2[1])
r3=scipy.stats.kendalltau(df,df1)
print([r3[0],r3[1]])
# Out:
# 0.9825113063742752 0.0027690279453106
# 0.9999999999999999 1.4042654220543672e-24
# [0.9999999999999999, 0.016666666666666666]

# %%
reg=scipy.stats.linregress(df,df1)
print(reg)
print(reg.slope)
print(reg.rvalue)
print(reg.pvalue)
print(reg.stderr)
print(reg.intercept)
print(reg.intercept_stderr)
# Out:
# LinregressResult(slope=4.6000000000000005, intercept=-103.60000000000002, rvalue=0.9825113063742752, pvalue=0.002769027945310598, stderr=0.503322295684715, intercept_stderr=13.608330781791919)
# 4.6000000000000005
# 0.9825113063742752
# 0.002769027945310598
# 0.503322295684715
# -103.60000000000002
# 13.608330781791919
